# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\python1\diabetes.csv")
data
# Out:
#         sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    Female      148             72             35        0  33.6
# 1      Male       85             66             29        0  26.6
# 2      Male      183             64              0        0  23.3
# 3      Male       89             66             23       94  28.1
# 4      Male      137             40             35      168  43.1
# ..      ...      ...            ...            ...      ...   ...
# 763    Male      101             76             48      180  32.9
# 764    Male      122             70             27        0  36.8
# 765    Male      121             72             23      112  26.2
# 766    Male      126             60              0        0  30.1
# 767  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_sex=LabelEncoder()

# %%
data['sex']=le_sex.fit_transform(data['sex'])
data
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0      148             72             35        0  33.6
# 1      1       85             66             29        0  26.6
# 2      1      183             64              0        0  23.3
# 3      1       89             66             23       94  28.1
# 4      1      137             40             35      168  43.1
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
data.head(5)
# Out:
#    sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0      148             72             35        0  33.6
# 1    1       85             66             29        0  26.6
# 2    1      183             64              0        0  23.3
# 3    1       89             66             23       94  28.1
# 4    1      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail(5)
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.columns
# Out:
# Index(['sex', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sex                       768 non-null    int32
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int32(1), int64(6)
# memory usage: 51.1 KB

# %%
data[45:]
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 45     1      180             66             39        0  42.0
# 46     1      146             56              0        0  29.7
# 47     1       71             70             27        0  28.0
# 48     0      103             66             32        0  39.1
# 49     1      105              0              0        0   0.0
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 45                      1.893   25        1
# 46                      0.564   29        0
# 47                      0.586   22        0
# ...

# %%
data[50:60]
# Out:
#     sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 50    0      103             80             11       82  19.4
# 51    0      101             50             15       36  24.2
# 52    1       88             66             21       23  24.4
# 53    1      176             90             34      300  33.7
# 54    1      150             66             42      342  34.7
# 55    1       73             50             10        0  23.0
# 56    1      187             68             39      304  37.7
# 57    0      100             88             60      110  46.8
# 58    1      146             82              0        0  40.5
# 59    1      105             64             41      142  41.5
#
#     DiabetesPedigreeFunction  Age  Outcome
# 50                     0.491   22        0
# 51                     0.526   26        0
# 52                     0.342   30        0
# 53                     0.467   58        1
# 54                     0.718   42        0
# ...

# %%
data.loc[1:5]
# Out:
#    sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1    1       85             66             29        0  26.6
# 2    1      183             64              0        0  23.3
# 3    1       89             66             23       94  28.1
# 4    1      137             40             35      168  43.1
# 5    1      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
data.loc[:20]
# Out:
#     sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0     0      148             72             35        0  33.6
# 1     1       85             66             29        0  26.6
# 2     1      183             64              0        0  23.3
# 3     1       89             66             23       94  28.1
# 4     1      137             40             35      168  43.1
# 5     1      116             74              0        0  25.6
# 6     0       78             50             32       88  31.0
# 7     0      115              0              0        0  35.3
# 8     1      197             70             45      543  30.5
# 9     1      125             96              0        0   0.0
# 10    1      110             92              0        0  37.6
# 11    1      168             74              0        0  38.0
# 12    1      139             80              0        0  27.1
# 13    0      189             60             23      846  30.1
# ...

# %%
data.loc[20,'BMI']
# Out:
# 39.3

# %%
data.loc[3:16,['BMI','Insulin']]
# Out:
#      BMI  Insulin
# 3   28.1       94
# 4   43.1      168
# 5   25.6        0
# 6   31.0       88
# 7   35.3        0
# 8   30.5      543
# 9    0.0        0
# 10  37.6        0
# 11  38.0        0
# 12  27.1        0
# 13  30.1      846
# 14  25.8      175
# 15  30.0        0
# 16  45.8      230

# %%
data.iloc[1:5,1:4]
# Out:
#    Glucose  BloodPressure  SkinThickness
# 1       85             66             29
# 2      183             64              0
# 3       89             66             23
# 4      137             40             35

# %%
data.iloc[:10,:6]
# Out:
#    sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0    0      148             72             35        0  33.6
# 1    1       85             66             29        0  26.6
# 2    1      183             64              0        0  23.3
# 3    1       89             66             23       94  28.1
# 4    1      137             40             35      168  43.1
# 5    1      116             74              0        0  25.6
# 6    0       78             50             32       88  31.0
# 7    0      115              0              0        0  35.3
# 8    1      197             70             45      543  30.5
# 9    1      125             96              0        0   0.0

# %%
data.iloc[[2,4,6,],[2,4,6]]
# Out:
#    BloodPressure  Insulin  DiabetesPedigreeFunction
# 2             64        0                     0.672
# 4             40      168                     2.288
# 6             50       88                     0.248

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
data.describe()
# Out:
#               sex     Glucose  BloodPressure  SkinThickness     Insulin  \
# count  768.000000  768.000000     768.000000     768.000000  768.000000
# mean     0.743490  120.894531      69.105469      20.536458   79.799479
# std      0.436991   31.972618      19.355807      15.952218  115.244002
# min      0.000000    0.000000       0.000000       0.000000    0.000000
# 25%      0.000000   99.000000      62.000000       0.000000    0.000000
# 50%      1.000000  117.000000      72.000000      23.000000   30.500000
# 75%      1.000000  140.250000      80.000000      32.000000  127.250000
# max      1.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.sample()
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 299    0      112             72              0        0  23.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 299                      0.84   58        0

# %%
data.dtypes
# Out:
# sex                           int32
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data.nunique()
# Out:
# sex                           2
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
data.count()
# Out:
# sex                         768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
data.corr()
# Out:
#                                sex   Glucose  BloodPressure  SkinThickness  \
# sex                       1.000000  0.014205       0.013376      -0.071692
# Glucose                   0.014205  1.000000       0.152590       0.057328
# BloodPressure             0.013376  0.152590       1.000000       0.207371
# SkinThickness            -0.071692  0.057328       0.207371       1.000000
# Insulin                  -0.095491  0.331357       0.088933       0.436783
# BMI                       0.004253  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction -0.070376  0.137337       0.041265       0.183928
# Age                       0.065569  0.263514       0.239528      -0.113970
# Outcome                  -0.014107  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# sex                      -0.095491  0.004253                 -0.070376
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
data[['BMI','Outcome']]
# Out:
#       BMI  Outcome
# 0    33.6        1
# 1    26.6        0
# 2    23.3        1
# 3    28.1        0
# 4    43.1        1
# ..    ...      ...
# 763  32.9        0
# 764  36.8        0
# 765  26.2        0
# 766  30.1        1
# 767  30.4        0
#
# [768 rows x 2 columns]

# %%
data[data['Age']>-12.3]
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0      148             72             35        0  33.6
# 1      1       85             66             29        0  26.6
# 2      1      183             64              0        0  23.3
# 3      1       89             66             23       94  28.1
# 4      1      137             40             35      168  43.1
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
data[data['Age']>-12.3].head(5)
# Out:
#    sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0      148             72             35        0  33.6
# 1    1       85             66             29        0  26.6
# 2    1      183             64              0        0  23.3
# 3    1       89             66             23       94  28.1
# 4    1      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data[data['Age']>-12.3].loc[4:8]
# Out:
#    sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4    1      137             40             35      168  43.1
# 5    1      116             74              0        0  25.6
# 6    0       78             50             32       88  31.0
# 7    0      115              0              0        0  35.3
# 8    1      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1

# %%
data[data['Age']>-12.3].loc[4:8,['Age','BloodPressure']]
# Out:
#    Age  BloodPressure
# 4   33             40
# 5   30             74
# 6   26             50
# 7   29              0
# 8   53             70

# %%
print("(Rows, columns): " + str(data.shape))
data.columns
# Out:
# (Rows, columns): (768, 9)
# Index(['sex', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data[data['Age']>-12.3].iloc[1:5,2:9]
# Out:
#    BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  \
# 1             66             29        0  26.6                     0.351   31
# 2             64              0        0  23.3                     0.672   32
# 3             66             23       94  28.1                     0.167   21
# 4             40             35      168  43.1                     2.288   33
#
#    Outcome
# 1        0
# 2        1
# 3        0
# 4        1

# %%
data.isna().sum()
# Out:
# sex                         0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.dropna()
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0      148             72             35        0  33.6
# 1      1       85             66             29        0  26.6
# 2      1      183             64              0        0  23.3
# 3      1       89             66             23       94  28.1
# 4      1      137             40             35      168  43.1
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
d=data.dropna(axis=0)
data.shape
# Out:
# (768, 9)

# %%
d.shape
# Out:
# (768, 9)

# %%
d
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0      148             72             35        0  33.6
# 1      1       85             66             29        0  26.6
# 2      1      183             64              0        0  23.3
# 3      1       89             66             23       94  28.1
# 4      1      137             40             35      168  43.1
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
data.nunique(axis=0)
# Out:
# sex                           2
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
print(data.isna().sum())
# Out:
# sex                         0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data["Outcome"].value_counts().plot(kind="bar", color=["red", "blue"]);

# %%
data.sex.value_counts()
# Out:
# 1    571
# 0    197
# Name: sex, dtype: int64

# %%
data["sex"].value_counts().plot(kind="bar", color=["Black", "Pink"]);

# %%
pd.crosstab(data.Outcome, data.sex).plot(kind="bar",
                                    figsize=(10,6),
                                    color=["pink","blue"])
plt.title(" disease frequency for sex")
plt.xlabel("0 = no disease, 1 = disease")
plt.ylabel("Amount")
plt.legend(["female", "male"])
plt.xticks(rotation=0);

# %%
# check the distribution of the age column with a histogram
data.Age.plot.hist();

# %%
data.corr()
# Out:
#                                sex   Glucose  BloodPressure  SkinThickness  \
# sex                       1.000000  0.014205       0.013376      -0.071692
# Glucose                   0.014205  1.000000       0.152590       0.057328
# BloodPressure             0.013376  0.152590       1.000000       0.207371
# SkinThickness            -0.071692  0.057328       0.207371       1.000000
# Insulin                  -0.095491  0.331357       0.088933       0.436783
# BMI                       0.004253  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction -0.070376  0.137337       0.041265       0.183928
# Age                       0.065569  0.263514       0.239528      -0.113970
# Outcome                  -0.014107  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# sex                      -0.095491  0.004253                 -0.070376
# Glucose                   0.331357  0.221071                  0.137337
# ...

# %%
corr_matrix = data.corr()
fig, ax =plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,
                 annot =True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (9.5, -0.5)

# %%
sns.countplot(data['Age'])
plt.show()
# Out:
# C:\Users\SAI SIDDHARTHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data['SkinThickness'])
plt.show()
# Out:
# C:\Users\SAI SIDDHARTHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(data.query('DiabetesPedigreeFunction > 2').DiabetesPedigreeFunction)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %%
sns.distplot(data['Glucose'])
# Out:
# C:\Users\SAI SIDDHARTHA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %%
data.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# sex                             AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Glucose                      AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# BloodPressure                AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# SkinThickness                AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Insulin                        AxesSubplot(0.125,0.518913;0.168478x0.16413)
# BMI                         AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# DiabetesPedigreeFunction    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Age                         AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# Outcome                        AxesSubplot(0.125,0.321957;0.168478x0.16413)
# dtype: object

# %%
data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
data.Age.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.Age.hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
sns.countplot(data.Outcome, palette = ['green', 'purple'])
plt.title ("0 : Patients not having a disease, 1: Patients having a disease")
# Out:
# C:\Users\SAI SIDDHARTHA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, '0 : Patients not having a disease, 1: Patients having a disease')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'Age', hue = 'Outcome', data = data)
plt.title("Heart disease depanding on ages")
plt.legend(["Patients not having disease ","Patients having disease "], loc= "upper right")

# %%
sns.pairplot(data)

# %%
data.plot.area
# Out:
# <bound method PlotAccessor.area of <pandas.plotting._core.PlotAccessor object at 0x000001532976AFD0>>

# %%
sns.violinplot(x='Outcome', y='Age', data=data)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %%
# split data into x and y
X = data.drop("Outcome",axis=1)
Y = data["Outcome"]
X
# Out:
#      sex  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      0      148             72             35        0  33.6
# 1      1       85             66             29        0  26.6
# 2      1      183             64              0        0  23.3
# 3      1       89             66             23       94  28.1
# 4      1      137             40             35      168  43.1
# ..   ...      ...            ...            ...      ...   ...
# 763    1      101             76             48      180  32.9
# 764    1      122             70             27        0  36.8
# 765    1      121             72             23      112  26.2
# 766    1      126             60              0        0  30.1
# 767    0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# ...

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=data.Age[data.Outcome==1], y=data.Glucose[(data.Outcome==1)], c='red')
plt.scatter(x=data.Age[data.Outcome==0], y=data.Glucose[(data.Outcome==0)],c='gray')
plt.legend(['Positive', 'Negative'])
plt.xlabel('Age')
plt.ylabel('Maximum Age')
plt.show()

# %%
data.count().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>
